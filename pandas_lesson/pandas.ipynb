# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Serijos

# %%
pavadinimai = ['x', 'y', 'z']
duomenys = [20, 30, 40]
serija = pd.Series(data=duomenys, index=pavadinimai)
serija
# Out:
# x    20
# y    30
# z    40
# dtype: int64

# %%
zodynas = {'a': 5, 'b' : 7, 'c' : 9, 'd': 11}
serija2 = pd.Series(zodynas)
serija2
# Out:
# a     5
# b     7
# c     9
# d    11
# dtype: int64

# %%
miestai = pd.Series([1,2,3,4,5],['Vilnius', 'Kaunas', 'Klaipeda', 'Panevezys', 'Siauliai'])
miestai
# Out:
# Vilnius      1
# Kaunas       2
# Klaipeda     3
# Panevezys    4
# Siauliai     5
# dtype: int64

# %%
miestai2 = pd.Series([1,2,3,4,5],['Vilnius', 'Kaunas', 'Lentvaris', 'Panevezys', 'Siauliai'])
miestai2
# Out:
# Vilnius      1
# Kaunas       2
# Lentvaris    3
# Panevezys    4
# Siauliai     5
# dtype: int64

# %%
miestai + miestai2
# Out:
# Kaunas        4.0
# Klaipeda      NaN
# Lentvaris     NaN
# Panevezys     8.0
# Siauliai     10.0
# Vilnius       2.0
# dtype: float64

# %% [markdown]
# # Data Frame

# %%
df1 = pd.DataFrame(np.random.rand(5,6), 
                    ['a', 'b', 'c', 'd', 'e'],
                    ['U', 'V', 'W', 'X', 'Y', 'Z']
)

df1
# Out:
#           U         V         W         X         Y         Z
# a  0.654553  0.909066  0.455767  0.647995  0.038351  0.253744
# b  0.886504  0.640380  0.245917  0.994558  0.440796  0.710083
# c  0.893163  0.106683  0.256503  0.983870  0.622515  0.425251
# d  0.367870  0.518973  0.948813  0.442072  0.320666  0.019537
# e  0.696089  0.443512  0.591120  0.815371  0.796329  0.686962

# %%
df1['U']
# Out:
# a    0.654553
# b    0.886504
# c    0.893163
# d    0.367870
# e    0.696089
# Name: U, dtype: float64

# %%
df1.loc['a']
# Out:
# U    0.654553
# V    0.909066
# W    0.455767
# X    0.647995
# Y    0.038351
# Z    0.253744
# Name: a, dtype: float64

# %%
df1[['U', 'X', 'Z']]
# Out:
#           U         X         Z
# a  0.654553  0.647995  0.253744
# b  0.886504  0.994558  0.710083
# c  0.893163  0.983870  0.425251
# d  0.367870  0.442072  0.019537
# e  0.696089  0.815371  0.686962

# %%
df1['naujas'] = [1, 2, 3, 4, 5]
df1
# Out:
#           U         V         W         X         Y         Z  naujas
# a  0.654553  0.909066  0.455767  0.647995  0.038351  0.253744       1
# b  0.886504  0.640380  0.245917  0.994558  0.440796  0.710083       2
# c  0.893163  0.106683  0.256503  0.983870  0.622515  0.425251       3
# d  0.367870  0.518973  0.948813  0.442072  0.320666  0.019537       4
# e  0.696089  0.443512  0.591120  0.815371  0.796329  0.686962       5

# %%
df1.drop('naujas', axis=1, inplace=True)
df1
# Out:
#           U         V         W         X         Y         Z
# a  0.654553  0.909066  0.455767  0.647995  0.038351  0.253744
# b  0.886504  0.640380  0.245917  0.994558  0.440796  0.710083
# c  0.893163  0.106683  0.256503  0.983870  0.622515  0.425251
# d  0.367870  0.518973  0.948813  0.442072  0.320666  0.019537
# e  0.696089  0.443512  0.591120  0.815371  0.796329  0.686962

# %%
df1.drop('e')
# Out:
#           U         V         W         X         Y         Z
# a  0.654553  0.909066  0.455767  0.647995  0.038351  0.253744
# b  0.886504  0.640380  0.245917  0.994558  0.440796  0.710083
# c  0.893163  0.106683  0.256503  0.983870  0.622515  0.425251
# d  0.367870  0.518973  0.948813  0.442072  0.320666  0.019537

# %%
df1.iloc[4]
# Out:
# U    0.696089
# V    0.443512
# W    0.591120
# X    0.815371
# Y    0.796329
# Z    0.686962
# Name: e, dtype: float64

# %%
df1.loc['c', 'X']
# Out:
# 0.983870013298777

# %%
df1.iloc[2, 3]
# Out:
# 0.983870013298777

# %%
df1.loc[['d' , 'e'], ['X', 'Y', 'Z']]
# Out:
#           X         Y         Z
# d  0.442072  0.320666  0.019537
# e  0.815371  0.796329  0.686962

# %%
df1.iloc[:,[2, 3]]
# Out:
#           W         X
# a  0.455767  0.647995
# b  0.245917  0.994558
# c  0.256503  0.983870
# d  0.948813  0.442072
# e  0.591120  0.815371

# %%
df1[df1> 0.4]
# Out:
#           U         V         W         X         Y         Z
# a  0.654553  0.909066  0.455767  0.647995       NaN       NaN
# b  0.886504  0.640380       NaN  0.994558  0.440796  0.710083
# c  0.893163       NaN       NaN  0.983870  0.622515  0.425251
# d       NaN  0.518973  0.948813  0.442072       NaN       NaN
# e  0.696089  0.443512  0.591120  0.815371  0.796329  0.686962

# %%
df1[df1['W'] > 0.4 ]
# Out:
#           U         V         W         X         Y         Z
# a  0.654553  0.909066  0.455767  0.647995  0.038351  0.253744
# d  0.367870  0.518973  0.948813  0.442072  0.320666  0.019537
# e  0.696089  0.443512  0.591120  0.815371  0.796329  0.686962

# %%
df1[df1['Y'] > 0.4][['Y']]
# Out:
#           Y
# b  0.440796
# c  0.622515
# e  0.796329

# %%
df1[(df1['W'] > 0.3) & (df1['Z'] > 0.3)][['U', 'Z']]
# Out:
#           U         Z
# e  0.696089  0.686962

# %% [markdown]
# # Reindeksavimas

# %%
df1.reset_index()
# Out:
#   index         U         V         W         X         Y         Z
# 0     a  0.654553  0.909066  0.455767  0.647995  0.038351  0.253744
# 1     b  0.886504  0.640380  0.245917  0.994558  0.440796  0.710083
# 2     c  0.893163  0.106683  0.256503  0.983870  0.622515  0.425251
# 3     d  0.367870  0.518973  0.948813  0.442072  0.320666  0.019537
# 4     e  0.696089  0.443512  0.591120  0.815371  0.796329  0.686962

# %%
naujas_indexas = 'Vilnius Kaunas Klaipeda Panevezys Siauliai'.split()
naujas_indexas
# Out:
# ['Vilnius', 'Kaunas', 'Klaipeda', 'Panevezys', 'Siauliai']

# %%
df1['Miestai'] = naujas_indexas
df1
# Out:
#           U         V         W         X         Y         Z    Miestai
# a  0.654553  0.909066  0.455767  0.647995  0.038351  0.253744    Vilnius
# b  0.886504  0.640380  0.245917  0.994558  0.440796  0.710083     Kaunas
# c  0.893163  0.106683  0.256503  0.983870  0.622515  0.425251   Klaipeda
# d  0.367870  0.518973  0.948813  0.442072  0.320666  0.019537  Panevezys
# e  0.696089  0.443512  0.591120  0.815371  0.796329  0.686962   Siauliai

# %%
df1
# Out:
#                   U         V         W         X         Y         Z
# Miestai
# Vilnius    0.654553  0.909066  0.455767  0.647995  0.038351  0.253744
# Kaunas     0.886504  0.640380  0.245917  0.994558  0.440796  0.710083
# Klaipeda   0.893163  0.106683  0.256503  0.983870  0.622515  0.425251
# Panevezys  0.367870  0.518973  0.948813  0.442072  0.320666  0.019537
# Siauliai   0.696089  0.443512  0.591120  0.815371  0.796329  0.686962

# %% [markdown]
# # Uzduotys

# %%
DF = pd.read_csv("miestai_isvalyti.csv")
DF.head(5)
# Out:
#      Miestas    2019    2011    2001    1989    1979    1970    1959    1923  \
# 0    Vilnius  540919  535631  542287  576747  475825  370153  236100  167400
# 1     Kaunas  286763  315993  378650  419745  370000  305600  216850   92446
# 2   Klaipėda  147898  162360  192954  202929  176648  140342   89500   35845
# 3   Šiauliai  100119  109328  133883  145629  118724   92375   59700   21387
# 4  Panevėžys   87148   99690  119749  126483  102303   74497   41100   19197
#
#      1897
# 0  154532
# 1   70920
# 2   20100
# 3   16128
# 4   12968

# %%
DF.set_index('Miestas')
DF.to_csv("miestai_isvalyti.csv")

# %%
DF.loc[6, '1923']
# Out:
# 9488

# %%
DF.iloc[:5]['1897']
DF[['1897']].head(5)
# Out:
#      1897
# 0  154532
# 1   70920
# 2   20100
# 3   16128
# 4   12968

# %%
DF[['Miestas','2019', '1970','1923']][:10]
# Out:
#        Miestas    2019    1970    1923
# 0      Vilnius  540919  370153  167400
# 1       Kaunas  286763  305600   92446
# 2     Klaipėda  147898  140342   35845
# 3     Šiauliai  100119   92375   21387
# 4    Panevėžys   87148   74497   19197
# 5       Alytus   50421   28165    6322
# 6  Marijampolė   35253   29073    9488
# 7    Mažeikiai   32711   13313    4300
# 8       Jonava   26715   14563    4115
# 9        Utena   25496   13309    4890

# %%
DF.shape[0]
# Out:
# 103

# %%
DF['nr'] = np.arange(len(DF))
DF
# Out:
#          Miestas    2019    2011    2001    1989    1979    1970    1959  \
# 0        Vilnius  540919  535631  542287  576747  475825  370153  236100
# 1         Kaunas  286763  315993  378650  419745  370000  305600  216850
# 2       Klaipėda  147898  162360  192954  202929  176648  140342   89500
# 3       Šiauliai  100119  109328  133883  145629  118724   92375   59700
# 4      Panevėžys   87148   99690  119749  126483  102303   74497   41100
# ..           ...     ...     ...     ...     ...     ...     ...     ...
# 98       Dusetos     560     717     914    1184    1357    1600    1806
# 99     Kavarskas     528     666     809     972    1113    1191    1287
# 100  Smalininkai     446     515     653     758     805     952    1100
# 101    Troškūnai     372     451     525     672    1174    1417    1495
# 102     Panemunė     210     274     329     398     506     545     539
#
#        1923    1897  row_num   nr
# 0    167400  154532        0    0
# ...

# %%
DF.drop('nr',axis=1, inplace=True)
DF
# Out:
#          Miestas    2019    2011    2001    1989    1979    1970    1959  \
# 0        Vilnius  540919  535631  542287  576747  475825  370153  236100
# 1         Kaunas  286763  315993  378650  419745  370000  305600  216850
# 2       Klaipėda  147898  162360  192954  202929  176648  140342   89500
# 3       Šiauliai  100119  109328  133883  145629  118724   92375   59700
# 4      Panevėžys   87148   99690  119749  126483  102303   74497   41100
# ..           ...     ...     ...     ...     ...     ...     ...     ...
# 98       Dusetos     560     717     914    1184    1357    1600    1806
# 99     Kavarskas     528     666     809     972    1113    1191    1287
# 100  Smalininkai     446     515     653     758     805     952    1100
# 101    Troškūnai     372     451     525     672    1174    1417    1495
# 102     Panemunė     210     274     329     398     506     545     539
#
#        1923    1897
# 0    167400  154532
# 1     92446   70920
# 2     35845   20100
# ...

# %%
DF[DF['1959'] == 0 ]
# Out:
#        Miestas   2019   2011   2001   1989  1979  1970  1959  1923  1897
# 14   Visaginas  18185  26804  29554  32438  6212     0     0     0     0
# 23  Elektrėnai  11276  12012  14050  15871  8466  6730     0     0     0

# %%
DF[DF['1897'] > DF['2019']]
# Out:
#                  Miestas  2019  2011  2001  1989  1979  1970  1959  1923  1897
# 41               Zarasai  6140  7349  8365  8916  7250  6624  4700  3785  6359
# 57            Švenčionys  4139  4980  5684  6469  5284  4617  4006     0  6025
# 58             Kalvarija  3858  4457  5090  5701  5879  5622  4698  4529  9378
# 63              Eišiškės  3071  3416  3765  3789  3467  3481  2532  2382  3196
# 65                Šeduva  2541  2895  3400  3584  3347  3309  3253  3186  4474
# 70               Vilkija  1898  2131  2338  2629  2371  2286  1996  2068  2012
# 72             Viekšniai  1670  1938  2270  2410  2781  2748  2734  2024  2951
# 76   Kudirkos Naumiestis  1480  1732  1997  2061  2090  2486  2574  3067  4595
# 79                Žagarė  1366  1712  2312  2649  2918  3386  3800  4730  8285
# 80              Salantai  1360  1615  1942  2431  2086  2156  2321  1942  2446
# 81               Linkuva  1277  1679  1797  2025  1876  1950  2144  1851  2077
# ...

# %%
DF[DF['2011'] < DF['2019']]
# Out:
#          Miestas    2019    2011    2001    1989    1979    1970    1959  \
# 0        Vilnius  540919  535631  542287  576747  475825  370153  236100
# 39   Šalčininkai    6753    6402    6722    6480    3857    1763    1676
# 85  Baltoji Vokė    1052    1047    1073    1128    1009    1065    1086
#
#       1923    1897
# 0   167400  154532
# 39     687     459
# 85       0       0

# %%
DF[(DF['1897'] > DF['1923']) & (DF['1923'] > DF['1959']) & (DF['1959'] > DF['1970'])]
# Out:
#                 Miestas  2019  2011  2001  1989  1979  1970  1959  1923  1897
# 76  Kudirkos Naumiestis  1480  1732  1997  2061  2090  2486  2574  3067  4595
# 79               Žagarė  1366  1712  2312  2649  2918  3386  3800  4730  8285

# %%
DF.iloc[:7]
# Out:
#        Miestas    2019    2011    2001    1989    1979    1970    1959  \
# 0      Vilnius  540919  535631  542287  576747  475825  370153  236100
# 1       Kaunas  286763  315993  378650  419745  370000  305600  216850
# 2     Klaipėda  147898  162360  192954  202929  176648  140342   89500
# 3     Šiauliai  100119  109328  133883  145629  118724   92375   59700
# 4    Panevėžys   87148   99690  119749  126483  102303   74497   41100
# 5       Alytus   50421   59964   71491   73015   55509   28165   12300
# 6  Marijampolė   35253   44885   48675   50887   38824   29073   19621
#
#      1923    1897
# 0  167400  154532
# 1   92446   70920
# 2   35845   20100
# 3   21387   16128
# 4   19197   12968
# 5    6322    3445
# 6    9488    6737

# %%
# DF = DF.set_index('Miestas')

# DF= DF.transpose().sort_index()

# lst = [DF[col].name for col in DF.columns if DF[col].is_monotonic_decreasing]

# DF = DF[[col for col in DF.columns if col in lst]]

# DF = DF.transpose()

# DF

# %% [markdown]
# # Papildoma manipuliacija

# %%
df = pd.DataFrame(np.random.rand(5,6), 
                  ['a', 'b', 'c', 'd', 'e'], 
                  ['U', 'V', 'W', 'X', 'Y', 'Z'])
df
# Out:
#           U         V         W         X         Y         Z
# a  0.215762  0.647757  0.664919  0.537632  0.376973  0.115946
# b  0.709618  0.789177  0.494038  0.052281  0.433933  0.986446
# c  0.401816  0.224375  0.268819  0.246456  0.062449  0.934216
# d  0.288626  0.993933  0.403887  0.967889  0.284704  0.122359
# e  0.064081  0.537324  0.231568  0.765654  0.519783  0.714975

# %%
# truthtable = df[df > .15].isnull()
# truthtable
filtered = df[df > .15]
truthtable = filtered.isnull()
truthtable
# Out:
#        U      V      W      X      Y      Z
# a  False  False  False  False  False   True
# b  False  False  False   True  False  False
# c  False  False  False  False   True  False
# d  False  False  False  False  False   True
# e   True  False  False  False  False  False

# %%
truthtable.sum()
# Out:
# U    1
# V    0
# W    0
# X    1
# Y    1
# Z    2
# dtype: int64

# %%
truthtable['X']
# Out:
# a    False
# b     True
# c    False
# d    False
# e    False
# Name: X, dtype: bool

# %%
filtered.dropna(axis=1)
# Out:
#           V         W
# a  0.647757  0.664919
# b  0.789177  0.494038
# c  0.224375  0.268819
# d  0.993933  0.403887
# e  0.537324  0.231568

# %%
filtered.dropna(thresh=5)
# Out:
#           U         V         W         X         Y         Z
# a  0.215762  0.647757  0.664919  0.537632  0.376973       NaN
# b  0.709618  0.789177  0.494038       NaN  0.433933  0.986446
# c  0.401816  0.224375  0.268819  0.246456       NaN  0.934216
# d  0.288626  0.993933  0.403887  0.967889  0.284704       NaN
# e       NaN  0.537324  0.231568  0.765654  0.519783  0.714975

# %%
filtered.fillna("Nereiksmingas")
# Out:
#                U         V         W              X              Y  \
# a       0.215762  0.647757  0.664919       0.537632       0.376973
# b       0.709618  0.789177  0.494038  Nereiksmingas       0.433933
# c       0.401816  0.224375  0.268819       0.246456  Nereiksmingas
# d       0.288626  0.993933  0.403887       0.967889       0.284704
# e  Nereiksmingas  0.537324  0.231568       0.765654       0.519783
#
#                Z
# a  Nereiksmingas
# b       0.986446
# c       0.934216
# d  Nereiksmingas
# e       0.714975

# %%
filtered.fillna(value=df["U"].mean())
# Out:
#           U         V         W         X         Y         Z
# a  0.215762  0.647757  0.664919  0.537632  0.376973  0.335980
# b  0.709618  0.789177  0.494038  0.335980  0.433933  0.986446
# c  0.401816  0.224375  0.268819  0.246456  0.335980  0.934216
# d  0.288626  0.993933  0.403887  0.967889  0.284704  0.335980
# e  0.335980  0.537324  0.231568  0.765654  0.519783  0.714975

# %% [markdown]
# # Grupavimas

# %%
duomenys = {'Šalis': ['Lietuva', 'Lietuva', 'Lietuva', 'Latvija', 'Latvija', 'Latvija', 'Estija', 'Estija', 'Estija'],
    'Miestas': ['Vilnius', 'Kaunas', 'Klaipėda', 'Ryga', 'Ventspilis', 'Daugpilis', 'Talinas', 'Tartu', 'Pernu'],
    'Gyv': [541, 287, 147, 716, 43, 105, 400, 101, 46]}
miestai = pd.DataFrame(duomenys)
miestai["Gyv"] *= 1000
miestai
# Out:
#      Šalis     Miestas     Gyv
# 0  Lietuva     Vilnius  541000
# 1  Lietuva      Kaunas  287000
# 2  Lietuva    Klaipėda  147000
# 3  Latvija        Ryga  716000
# 4  Latvija  Ventspilis   43000
# 5  Latvija   Daugpilis  105000
# 6   Estija     Talinas  400000
# 7   Estija       Tartu  101000
# 8   Estija       Pernu   46000

# %%
grupuoti = miestai.groupby('Šalis')
grupuoti.sum()
# Out:
#             Gyv
# Šalis
# Estija   547000
# Latvija  864000
# Lietuva  975000

# %%
grupuoti.count()
# Out:
#          Miestas  Gyv
# Šalis
# Estija         3    3
# Latvija        3    3
# Lietuva        3    3

# %%
grupuoti.max()
# Out:
#             Miestas     Gyv
# Šalis
# Estija        Tartu  400000
# Latvija  Ventspilis  716000
# Lietuva     Vilnius  541000

# %%
grupuoti.min()
# Out:
#            Miestas     Gyv
# Šalis
# Estija       Pernu   46000
# Latvija  Daugpilis   43000
# Lietuva     Kaunas  147000

# %%
grupuoti.sum().loc["Lietuva"]
# Out:
# Gyv    975000
# Name: Lietuva, dtype: int64

# %%
grupuoti.describe()
# Out:
#           Gyv                                                              \
#         count           mean            std       min       25%       50%
# Šalis
# Estija    3.0  182333.333333  190500.218723   46000.0   73500.0  101000.0
# Latvija   3.0  288000.000000  371952.954014   43000.0   74000.0  105000.0
# Lietuva   3.0  325000.000000  199729.817504  147000.0  217000.0  287000.0
#
#
#               75%       max
# Šalis
# Estija   250500.0  400000.0
# Latvija  410500.0  716000.0
# Lietuva  414000.0  541000.0

# %%
grupuoti.describe().transpose()
# Out:
# Šalis             Estija        Latvija        Lietuva
# Gyv count       3.000000       3.000000       3.000000
#     mean   182333.333333  288000.000000  325000.000000
#     std    190500.218723  371952.954014  199729.817504
#     min     46000.000000   43000.000000  147000.000000
#     25%     73500.000000   74000.000000  217000.000000
#     50%    101000.000000  105000.000000  287000.000000
#     75%    250500.000000  410500.000000  414000.000000
#     max    400000.000000  716000.000000  541000.000000

# %%
grupuoti.describe().transpose()['Estija']
# Out:
# Gyv  count         3.000000
#      mean     182333.333333
#      std      190500.218723
#      min       46000.000000
#      25%       73500.000000
#      50%      101000.000000
#      75%      250500.000000
#      max      400000.000000
# Name: Estija, dtype: float64

# %% [markdown]
# # DF Jungimas

# %%
dalis_miestu = miestai[:6]
dalis_miestu
# Out:
#      Šalis     Miestas     Gyv
# 0  Lietuva     Vilnius  541000
# 1  Lietuva      Kaunas  287000
# 2  Lietuva    Klaipėda  147000
# 3  Latvija        Ryga  716000
# 4  Latvija  Ventspilis   43000
# 5  Latvija   Daugpilis  105000

# %%
kiti_miestai = miestai[6:]
kiti_miestai
# Out:
#     Šalis  Miestas     Gyv
# 6  Estija  Talinas  400000
# 7  Estija    Tartu  101000
# 8  Estija    Pernu   46000

# %%
visi_miestai = pd.concat([dalis_miestu, kiti_miestai])
visi_miestai
# Out:
#      Šalis     Miestas     Gyv
# 0  Lietuva     Vilnius  541000
# 1  Lietuva      Kaunas  287000
# 2  Lietuva    Klaipėda  147000
# 3  Latvija        Ryga  716000
# 4  Latvija  Ventspilis   43000
# 5  Latvija   Daugpilis  105000
# 6   Estija     Talinas  400000
# 7   Estija       Tartu  101000
# 8   Estija       Pernu   46000

# %%
desnieji = kiti_miestai.reset_index()
desnieji.drop(columns='index', inplace = True)
desnieji
# Out:
#     Šalis  Miestas     Gyv
# 0  Estija  Talinas  400000
# 1  Estija    Tartu  101000
# 2  Estija    Pernu   46000

# %%
lenkija = {'Šalis': ['Lenkija', 'Lenkija', 'Lenkija'],
'Miestas':['Varšuva', 'Vroclavas', 'Gdanskas'],
'Gyv': [1688000, 638000, 461000]}
pl = pd.DataFrame(lenkija)
desnieji1 = pd.concat([desnieji, pl])
desnieji1.reset_index().drop(columns='index')
desnieji1
# Out:
#      Šalis    Miestas      Gyv
# 0   Estija    Talinas   400000
# 1   Estija      Tartu   101000
# 2   Estija      Pernu    46000
# 0  Lenkija    Varšuva  1688000
# 1  Lenkija  Vroclavas   638000
# 2  Lenkija   Gdanskas   461000

# %%
pagrindiniai_miestai = pd.concat([dalis_miestu, desnieji], axis= 1)
pagrindiniai_miestai
# Out:
#      Šalis     Miestas     Gyv   Šalis  Miestas       Gyv
# 0  Lietuva     Vilnius  541000  Estija  Talinas  400000.0
# 1  Lietuva      Kaunas  287000  Estija    Tartu  101000.0
# 2  Lietuva    Klaipėda  147000  Estija    Pernu   46000.0
# 3  Latvija        Ryga  716000     NaN      NaN       NaN
# 4  Latvija  Ventspilis   43000     NaN      NaN       NaN
# 5  Latvija   Daugpilis  105000     NaN      NaN       NaN

# %%
keyX = "A B C D E F".split()
dalis_miestu["key"] = keyX
dalis_miestu
